# %%
import pandas as pd
df=pd.read_csv("finance_data.csv") #read csv file in pandas
df.head() #prints first 5 rows from the dataset
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
type(df)  #to check the type of dataset
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns #prints all columns present in the dataframe
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
df.shape #displays number of rows and columns
# Out:
# (40, 24)

# %%
df.info() #gives info of the dataset including null/not-null and dtype of the values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
df.describe()  #gives descriptive summary of the dataframe
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
#df.value_counts().tail(2)  #prints the count of the each value present in the dataset

#alternate method
df["gender"].value_counts()
# Out:
# Male      25
# Female    15
# Name: gender, dtype: int64

# %%
#to set any column in the dataset as index column
#df=pd.read_csv("finance_data.csv",index_col="age")
df
#alternate method
df.set_index("age",inplace=False)
#to reset index col
#df.reset_index(inplace=True)
#df
# Out:
#      gender Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# age
# 34   Female                Yes             1              2           5
# 23   Female                Yes             4              3           2
# 30     Male                Yes             3              6           4
# 22     Male                Yes             2              1           3
# 24   Female                 No             2              1           3
# 24   Female                 No             7              5           4
# 27   Female                Yes             3              6           4
# 21     Male                Yes             2              3           7
# 35     Male                Yes             2              4           7
# 31     Male                Yes             1              3           7
# 35   Female                Yes             2              4           7
# 29     Male                Yes             2              5           7
# ...

# %%
#to sort values in ascending or descending order
#df.sort_values(by="Mutual_Funds",ascending=False) 
#alternate method
df["Equity_Market"].sort_values()
#sorting multiple values
df.sort_values(by=["Equity_Market","Mutual_Funds"], ascending=[False,True],inplace=True)
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 2     Male   30                Yes             3              6           4
# 6   Female   27                Yes             3              6           4
# 11    Male   29                Yes             2              5           7
# 30    Male   27                Yes             4              5           1
# 5   Female   24                 No             7              5           4
# 35    Male   30                Yes             1              4           6
# 8     Male   35                Yes             2              4           7
# 10  Female   35                Yes             2              4           7
# 20    Male   29                Yes             2              4           7
# 21  Female   24                Yes             2              4           5
# 23    Male   25                Yes             2              4           6
# ...

# %%
#prints the length of string present in the column
df["Reason_Mutual"].apply(len)
# Out:
# 2     12
# 6     14
# 11    20
# 30    12
# 5     20
# 35    14
# 8     20
# 10    14
# 20    14
# 21    14
# 23    14
# 31    14
# 32    20
# 36    14
# 38    20
# 19    20
# 22    14
# 25    14
# 26    20
# 29    12
# 37    14
# 9     20
# 7     14
# 13    20
# 14    14
# 15    20
# 24    14
# 27    20
# 28    14
# 33    14
# 34    14
# 1     14
# 39    14
# 0     14
# 12    14
# 16    20
# 17    14
# 18    14
# 3     20
# 4     14
# Name: Reason_Mutual, dtype: int64

# %%
#to find largest and smallest value in the datafarme
#df["Equity_Market"].nlargest()
#df["Equity_Market"].nsmallest()

#alternate method
df.nlargest(10,"Equity_Market")
df.nsmallest(10,"Mutual_Funds")
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 35    Male   30                Yes             1              4           6
# 9     Male   31                Yes             1              3           7
# 0   Female   34                Yes             1              2           5
# 12  Female   21                 No             1              2           3
# 11    Male   29                Yes             2              5           7
# 8     Male   35                Yes             2              4           7
# 10  Female   35                Yes             2              4           7
# 20    Male   29                Yes             2              4           7
# 21  Female   24                Yes             2              4           5
# 23    Male   25                Yes             2              4           6
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Duration  \
# 35                 5               3    2     7  ...  3-5 years
# ...

# %%
#to drop any blank or nan values
#df.dropna()
df.dropna(axis=0,how="all")
#df.shape
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 2     Male   30                Yes             3              6           4
# 6   Female   27                Yes             3              6           4
# 11    Male   29                Yes             2              5           7
# 30    Male   27                Yes             4              5           1
# 5   Female   24                 No             7              5           4
# 35    Male   30                Yes             1              4           6
# 8     Male   35                Yes             2              4           7
# 10  Female   35                Yes             2              4           7
# 20    Male   29                Yes             2              4           7
# 21  Female   24                Yes             2              4           5
# 23    Male   25                Yes             2              4           6
# ...

# %%
#will return boolean values was true wherever na/blank value is present
df.isna()
# Out:
#     gender    age  Investment_Avenues  Mutual_Funds  Equity_Market  \
# 2    False  False               False         False          False
# 6    False  False               False         False          False
# 11   False  False               False         False          False
# 30   False  False               False         False          False
# 5    False  False               False         False          False
# 35   False  False               False         False          False
# 8    False  False               False         False          False
# 10   False  False               False         False          False
# 20   False  False               False         False          False
# 21   False  False               False         False          False
# 23   False  False               False         False          False
# 31   False  False               False         False          False
# 32   False  False               False         False          False
# ...

# %%
#fills value with value passed in the argument whereever na value is present
df.fillna(0)
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 2     Male   30                Yes             3              6           4
# 6   Female   27                Yes             3              6           4
# 11    Male   29                Yes             2              5           7
# 30    Male   27                Yes             4              5           1
# 5   Female   24                 No             7              5           4
# 35    Male   30                Yes             1              4           6
# 8     Male   35                Yes             2              4           7
# 10  Female   35                Yes             2              4           7
# 20    Male   29                Yes             2              4           7
# 21  Female   24                Yes             2              4           5
# 23    Male   25                Yes             2              4           6
# ...

# %%
#to replace any values in dataframe
#replaced all values with number 6 with number 5
df.replace(6,5,inplace=True) #helps to replace values in a col

#replaced age column value 30 with value 29
#df["age"].replace(30,29,inplace=True)
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 2     Male   30                Yes             3              5           4
# 6   Female   27                Yes             3              5           4
# 11    Male   29                Yes             2              5           7
# 30    Male   27                Yes             4              5           1
# 5   Female   24                 No             7              5           4
# 35    Male   30                Yes             1              4           5
# 8     Male   35                Yes             2              4           7
# 10  Female   35                Yes             2              4           7
# 20    Male   29                Yes             2              4           7
# 21  Female   24                Yes             2              4           5
# 23    Male   25                Yes             2              4           5
# ...

# %%
#to see dtypes of columns
df.dtypes
#to change dtype of any column
df["age"].astype(float)

#avg\mean can be found onnly when values are in float
df["age"].mean()
#median
df["age"].median()
#mode
df["age"].mode()
# Out:
# 0    27
# Name: age, dtype: int64

# %%
#prints all unique values in that particular column
df["gender"].unique()
#prints the number of unqiue values present 
df["gender"].nunique()
# Out:
# 2

# %%
#FILTERING DATA

# %%
#filtering data where age is between 19 and 25
young_gen=df[(df["age"]>19) & (df["age"]<25)]
young_gen
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 5   Female   24                 No             7              5           4
# 21  Female   24                Yes             2              4           5
# 7     Male   21                Yes             2              3           7
# 1   Female   23                Yes             4              3           2
# 12  Female   21                 No             1              2           3
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 5                  5               3    1     2  ...          1-3 years
# 21                 5               3    1     7  ...          3-5 years
# 7                  4               5    1     5  ...          3-5 years
# ...
